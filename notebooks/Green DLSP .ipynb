# %%
import re
import math

import altair as alt ##
import numpy as np
import pandas as pd
import plotly.express as px

# %% [markdown]
# ## Import data from CSVs

# %%
dbutils.fs.cp("dbfs:/FileStore/shared_uploads/barryjames028@gmail.com/AWS_EC2_Carbon_Footprint_Dataset.xlsx", "file:/databricks/driver/AWS_EC2_Carbon_Footprint_Dataset.xlsx")
dbutils.fs.cp("dbfs:/FileStore/shared_uploads/barryjames028@gmail.com/codecarbon_carbontracking.csv", "file:/databricks/driver/codecarbon_carbontracking.csv")
df_ec2 = pd.read_excel("/databricks/driver/AWS_EC2_Carbon_Footprint_Dataset.xlsx", "EC2 Instances Dataset")
df_ec2 = df_ec2.set_index("Instance type")

# %%
df_intensity = pd.read_excel("/databricks/driver/AWS_EC2_Carbon_Footprint_Dataset.xlsx", "AWS Regions Mix Intensity")
df_intensity = df_intensity.set_index("Region")

# %%
dbutils.fs.cp("dbfs:/FileStore/shared_uploads/barryjames028@gmail.com/datadog_cpu_memory_usage.csv", "file:/databricks/driver/datadog_cpu_memory_usage.csv")
df_dd = pd.read_csv("/databricks/driver/datadog_cpu_memory_usage.csv").dropna()

# %% [markdown]
# We created this query in datadog based on metrics from [this agent for datadog](https://docs.datadoghq.com/agent/kubernetes/)

# %% [markdown]
# ![image.png](attachment:9564d2a1-ea03-43c0-8967-6c60f102bc22.png)

# %% [markdown]
# The `from` part of the query is just to filter out pods that belongs to the age pipeline in the production enviroment. Since `kubernetes.memory.rss` is given in bytes and we need it in GB we divide by 1073741824 (the number of bytes in a GB). `kubernetes.cpu.usage.total` is given in nanocores so we divide by 1e9 to get in cores. To get the neccesary information about the hardware we need to sum both metrics by the AWS EC2 instance type, and to know what part of the pipeline the executing job belongs to we use the pod name.

# %% [markdown]
# ![image.png](attachment:a37dce2e-8667-4657-af4d-ad08a7e967e2.png)

# %%
def to_query_value(query):
    if "memory.rss" in query:
        return "memory"
    elif "cpu.usage" in query:
        return "cpu"
    else:
        return np.nan

def parse_query(df: pd.DataFrame):
    """
    Extract instance types and pipeline stage names from the query string

    """
    df["query_value"] = df["query"].apply(to_query_value)
    df = df.drop(axis=1, labels="query")

    df["instance-type"] = df["group"].apply(lambda x: re.split(';|:', x)[1])
    df["pod_name"] = df["group"].apply(lambda x: re.split(';|:', x)[3])
    df["stage_name"] = df["pod_name"].str.replace("ate-age-v2-", "").str.split("-").str[0]
    df["stage_name"] = df["stage_name"].apply(lambda x:
                                                    "eventspreprocessed" if "eventspreprocessed" in x else x)
    df["time"] = pd.to_datetime(df_dd["time"])

    return df.drop(columns=['group'])

# %%
df_dd = parse_query(df_dd)

# %%
## plotly not giving better histograms so instead seaborn, hisplot and try to use different , number of bins=50

fig = px.histogram(df_dd,
                   x="value",
                   facet_col="query_value",
                   nbins=200).update_xaxes(matches=None)

fig.update_xaxes(title_text="GB", row=1, col=1)
fig.update_xaxes(title_text="vCPUs", row=1, col=2)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="ba401d8f-9514-428e-b12c-40164ecc2cee" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
.929971,28.929971,28.929971,1.025299,1.566837,1.574966,1.578974,1.629059,1.662579,1.662579,1.662579,1.507952,1.655952,2.419505,2.213408,2.365282,2.072631,2.454648,2.362476,2.570207,2.626872,2.683878,2.835895,2.962338,2.890462,2.689291,2.950633,2.73462,2.904027,2.844081,3.090071,2.864169,3.002047,3.019056,3.129596,3.398823,3.324865,3.320427,3.571439,3.354705,3.222013,3.222013,3.222013,1.289574,1.81395,1.939745,2.848867,2.749956,2.749956,2.749956,1.050408,1.705256,1.910695,1.994741,2.171989,2.197433,2.146559,2.183771,2.009516,2.014946,2.053758,2.164266,2.299466,2.301 ...

# %%
def value_to_util_frac(df, value, query_value, instance_type):
    if query_value == "memory":
        return value / df["Instance Memory (in GB)"][instance_type]
    elif query_value == "cpu":
        return value / df["Instance vCPU"][instance_type] # "Platform Total Number of vCPU"
    else:
        raise NotImplementedError()


df_dd["util_frac"] = df_dd.apply(lambda row: value_to_util_frac(
    df_ec2, row["value"], row["query_value"], row["instance-type"]), axis=1)
df_dd = df_dd.drop(columns="value", axis=1)

# %%
## seaborn for histogram and kDE=TRUE
#sns.histplot(data = births, x = 'Maternal Pregnancy Weight', bins = 20);
#sns.rugplot(data = births, x = 'Maternal Pregnancy Weight', color = "red");
#sns.histplot(data = births, x = 'Maternal Pregnancy Weight', kde = True);  ## smooth curve of the distribution of value without the need of bins
#sns.rugplot(data = births, x = 'Maternal Pregnancy Weight', color = "red");


px.histogram(df_dd, x="util_frac", facet_col="query_value", nbins=150).update_xaxes(matches=None)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="530d10fe-ace6-4c83-9998-37c3bdf9ad15" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("530d10fe-ace6-4c83-9998-37c3bdf9ad15")) {                    Plotly.newPlot(                        "530d10fe-ace6-4c83-9998-37c3bdf9ad15",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"query_value=memory<br>util_frac=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":150,"offsetgroup":"","orientation":"v","showlegend":false,"x":[0.01126828125,0.147886265625,0.164113859375,0.177977828125,0.1898338125,0.20212753125,0.215055875,0.228338140625,0.298176140625,0.39057359375,0.3978239375,0.3978308125,0.39783690625,0.3978386875,0.3978386875,0.3978386875,0.0477774375,0.0836351640625,0.094126609375,0.0953453828125,0.0955614609375,0.14239346875,0.1704035390625,0.1877825546875,0.20326740625,0.2048871015625,0.2062786796875,0.2063037890625,0.2063037890625,0.2063037890625,0.0395600078125,0.0749606953125,0.0753535625,0.07552365625,0.0756795390625,0.1167923046875,0.163216828125,0.1819264921875,0.1996450546875,0.2020244609375,0.2036756171875,0.2042245,0.2042245,0.2042245,0.027735578125,0.041048203125,0.034203734375,0.04167153125,0.0463685,0.038333421875,0.038333421875,0.038333421875,0.0016132265625,0.003215421875,0.003215421875,0.083705578125,0.0838407890625,0.0848518046875,0.0885298359375,0.1049644296875,0.190964265625,0.1915092734375,0.1918821953125,0.199547875,0.2016348125,0.2023956953125,0.2026792578125,0.20574775,0.2088526953125,0.20914340625,0.20924296875,0.20924296875,0.20924296875,8.4609375e-06,0.0508340078125,0.075802765625,0.0760010859375,0.0760761953125,0.076189953125,0.130541953125,0.1637295703125,0.1673493515625,0.1681260546875,0.1708353984375,0.1736463828125,0.1741840703125,0.1741840703125,0.1741840703125,0.06560896875,0.0653848125,0.0653848125,0.0653848125,0.015479578125,0.031079609375,0.026768453125,0.0363028125,0.03909396875,0.03909396875,0.03909396875,2.0140625e-05,6.5984375e-05,6.5984375e-05,7.9984375e-05,8.934375e-05,8.934375e-05,9.359375e-06,5.996875e-05,5.996875e-05,5.996875e-05,6.4078125e-05,6.4078125e-05,6.4078125e-05,0.0096763125,0.01372534375,0.0171953359375,0.018201421875,0.018201421875,0.018201421875,0.0095569609375,0.0201117578125,0.0201117578125,0.0201117578125,0.068755265625,0.087127890625,0.0875666171875,0.0877968359375,0.095278328125,0.096434328125,0.09653840625,0.10293625,0.1266178671875,0.2068066015625,0.234195375,0.2421435234375,0.2421531953125,0.2424328359375,0.24253525,0.242521671875,0.244438546875,0.2452809453125,0.2455014453125,0.245629328125,0.245629328125,0.245629328125,0.020877671875,0.03197709375,0.03197709375,0.03197709375,0.0010911328125,0.0077652421875,0.0090227109375,5.4e-05,0.05449284375,0.07433965625,0.0888268125,0.0888268125,0.0888268125,3.3671875e-05,0.018878546875,0.026645,0.028029609375,0.032032546875,0.029442796875,0.02847078125,0.030255078125,0.0298920625,0.033037765625,0.033469203125,0.03276071875,0.034287359375,0.03245509375,0.030263140625,0.036149015625,0.035362875,0.037837484375,0.03925840625,0.03981028125,0.037477109375,0.040093609375,0.038465109375,0.035926078125,0.035829109375,0.036099109375,0.03770046875,0.03997790625,0.0418885,0.04017040625,0.03666025,0.0375390625,0.0457553125,0.04202509375,0.043360046875,0.043690265625,0.0436134375,0.04354778125,0.04399371875,0.041833171875,0.042907734375,0.039063359375,0.04315746875,0.04630703125,0.044379171875,0.0411888125,0.04274878125,0.04542803125,0.044058078125,0.046620734375,0.046620734375,0.046620734375,0.018104546875,0.024668984375,0.024699984375,0.024715390625,0.024734734375,0.02475046875,0.02475834375,0.02475834375,0.02475834375,0.017337046875,0.026850875 ...

# %%
def preprocess_dd_data(df: pd.DataFrame):
    na_pods_count = df[df["pod_name"] == "N/A"]["query_value"].value_counts()
    print(f"Encountered {na_pods_count.values} pods with N/A name.")

    na_pods_util_frac = df[(df["pod_name"] == "N/A")]["util_frac"].sum() / df["util_frac"].sum()
    print(f"Fraction of memory usage, represented by N/A pods: {na_pods_util_frac}.")

    df_dd = df[df["pod_name"] != "N/A"]

    return df_dd

df_dd = preprocess_dd_data(df_dd)
# Out:
# Encountered [157] pods with N/A name.
# Fraction of memory usage, represented by N/A pods: 3.4032300630672487e-06.

# %%
grouping_cols = df_dd.columns.to_list()
grouping_cols.remove("util_frac")

# %%
# Lookup Power from utlization
instances_in_use = df_dd["instance-type"].unique()
df_ec2 = df_ec2.loc[instances_in_use]
df_ec2
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Release Date</th>
#       <th>Instance vCPU</th>
#       <th>Platform Total Number of vCPU</th>
#       <th>Platform CPU Name</th>
#       <th>Instance Memory (in GB)</th>
#       <th>Platform Memory (in GB)</th>
#       <th>Storage Info (Type and Size in GB)</th>
#       <th>Storage Type</th>
#       <th>Platform Storage Drive Quantity</th>
#       <th>Platform GPU Quantity</th>
#       <th>...</th>
#       <th>Instance @ 10%</th>
#       <th>Instance @ 50%</th>
#       <th>Instance @ 100%</th>
#       <th>Platform Additional Memory Scope 3 Emissions</th>
#       <th>Platform Additional Storage Scope 3 Emissions</th>
#       <th>Platform Additional GPU Scope 3 Emissions</th>
#       <th>Platform Additional CPU Scope 3 Emissions</th>
#       <th>Total Platform Scope 3 Emissions  (kgCO₂eq)</th>
#       <th>Instance Hourly Manufacturing Emissions (gCO₂eq)</th>
#       <th>Hardware Information on AWS Documentation &amp; Comments</th>
#     </tr>
#     <tr>
#       <th>Instance type</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>m5.4xlarge</th>
#       <td>November 2017</td>
#       <td>16.0</td>
#       <td>96</td>
#       <td>Xeon Platinum 8175M</td>
#       <td>64.0</td>
#       <td>384.0</td>
#       <td>EBS-Only</td>
#       <td>EBS</td>
#       <td>0.0</td>
#       <td>NaN</td>
#       <td>...</td>
#       <td>55.836667</td>
#       <td>112.966667</td>
#       <td>159.630833</td>
#       <td>510.3792</td>
#       <td>0</td>
#       <td>0</td>
#       <td>100</td>
#       <td>1610.3792</td>
#       <td>7.766103</td>
#       <td>Up to 3.1 GHz Intel Xeon Platinum 8175M</td>
#     </tr>
#     <tr>
#       <th>r5.4xlarge</th>
#       <td>July 2018</td>
#       <td>16.0</td>
#       <td>96</td>
#       <td>Xeon Platinum 8175M</td>
#       <td>128.0</td>
#       <td>768.0</td>
#       <td>EBS-Only</td>
#       <td>EBS</td>
#       <td>0.0</td>
#       <td>NaN</td>
#       <td>...</td>
#       <td>71.235000</td>
#       <td>152.650000</td>
#       <td>223.599167</td>
#       <td>1042.9488</td>
#       <td>0</td>
#       <td>0</td>
#       <td>100</td>
#       <td>2142.9488</td>
#       <td>10.334437</td>
#       <td>Up to 3.1 GHz Intel Xeon Platinum 8000 series ...</td>
#     </tr>
#     <tr>
#       <th>m4.4xlarge</th>
#       <td>June 2015</td>
#       <td>16.0</td>
#       <td>72</td>
#       <td>Xeon E5-2686 v4</td>
#       <td>64.0</td>
#       <td>256.0</td>
#       <td>EBS-Only</td>
#       <td>EBS</td>
#       <td>0.0</td>
#       <td>NaN</td>
#       <td>...</td>
#       <td>54.280000</td>
#       <td>84.131111</td>
#       <td>113.762778</td>
#       <td>332.8560</td>
#       <td>0</td>
#       <td>0</td>
#       <td>100</td>
#       <td>1432.8560</td>
#       <td>9.213323</td>
#       <td>2.3 GHz Intel Xeon E5-2686 v4 (Broadwell) or 2...</td>
#     </tr>
#     <tr>
#       <th>c5d.4xlarge</th>
#       <td>May 2018</td>
#       <td>16.0</td>
#       <td>72</td>
#       <td>Xeon Platinum 8124M</td>
#       <td>32.0</td>
#       <td>192.0</td>
#       <td>1 x 400 NVMe SSD</td>
#       <td>SSD</td>
#       <td>2.0</td>
#       <td>NaN</td>
#       <td>...</td>
#       <td>62.541667</td>
#       <td>106.231111</td>
#       <td>143.722778</td>
#       <td>244.0944</td>
#       <td>200</td>
#       <td>0</td>
#       <td>100</td>
#       <td>1200</td>
#       <td>100</td>
#       <td>3010.3792</td>
#       <td>14.517647</td>
#       <td>NVIDIA T4 GPU and custom Intel Cascade Lake CPUs</td>
#     </tr>
#     <tr>
#       <th>c5.4xlarge</th>
#       <td>November 2016</td>
#       <td>16.0</td>
#       <td>72</td>
#       <td>Xeon Platinum 8124M</td>
#       <td>32.0</td>
#       <td>192.0</td>
#       <td>EBS-Only</td>
#       <td>EBS</td>
#       <td>0.0</td>
#       <td>NaN</td>
#       <td>...</td>
#       <td>62.541667</td>
#       <td>106.231111</td>
#       <td>143.722778</td>
#       <td>244.0944</td>
#       <td>0</td>
#       <td>0</td>
#       <td>100</td>
#       <td>1344.0944</td>
#       <td>8.642582</td>
#       <td>Up to 3.5GHz 2nd generation Intel Xeon Scalabl...</td>
#     </tr>
#   </tbody>
# </table>
# <p>10 rows × 37 columns</p>
# </div>

# %% [markdown]
# ### Interpolation

# %%
cpu_loolup_col_prefix = "PkgWatt"    ## power consumed by CPUs
ram_loolup_col_prefix = "RAMWatt"
gpu_loolup_col_prefix = "GPUWatt"
power_delta_col = "Delta Full Machine"

import scipy.interpolate

def util_to_power(df, util_value, util_type, instance_type):
    x = [0, 0.1, 0.5, 1]   ## utilization ratio
    if util_type == "cpu":
        col_prefix = cpu_loolup_col_prefix
    elif util_type == "memory":
        col_prefix = ram_loolup_col_prefix
    elif util_type == "gpu":
        col_prefix = gpu_loolup_col_prefix
    else:
        raise NotImplementedError(f"handling for {util_type} not implemented")
    y_cols = [f"{col_prefix} @ Idle"] + [f"{col_prefix} @ {str(int(i*100))}%"  for i in x[1:]]
    y = df.loc[instance_type].loc[y_cols]
    return scipy.interpolate.interp1d(x,y)(util_value)    ## interpolate utilization ratio to the power consumption


def instace_type_util_to_delta_power(df, any_sample_values, instance_type):
    return any_sample_values.map({True: df.loc[instance_type].loc[power_delta_col], False: np.nan})


def instace_type_util_to_gpu_power(any_sample_values, instance_type, measured_avg_gpu_power_dict):
    return any_sample_values.map({
        True: measured_avg_gpu_power_dict[instance_type] if instance_type in gpu_instances.index else np.nan,
        False: np.nan
    })

# %%
cols = df_ec2.columns
df_power_plot = df_ec2[cols[cols.str.contains(cpu_loolup_col_prefix) | cols.str.contains(ram_loolup_col_prefix)]]

def colname_to_frac(c):
    int_str = c.split("@ ")[1].strip("%")
    int_str = "0" if "Idle" in int_str else int_str
    return float(int_str) / 100.0

df_power_plot.columns = pd.MultiIndex.from_tuples(
    [
        (colname_to_frac(c),"cpu" if cpu_loolup_col_prefix in c else "ram") for c in df_power_plot.columns
    ],
    names=('util', 'factor'))

df_plot_power = pd.melt(df_power_plot.stack("util").reset_index(level=1),
                        id_vars=["util"],
                        ignore_index=False).reset_index().rename(columns={
    "value": "power [W]",
    "util": "utilization fraction"
})
### add symbols-- try to change this visualization
## matplotlib

px.line(df_plot_power,
        x="utilization fraction",
        y="power [W]",
        facet_col="factor",
        color="Instance type",
        title="Util vs Power per factor for instances in use")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="1eb544fe-4300-4a82-8c82-41ba6e3903df" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1eb544fe-4300-4a82-8c82-41ba6e3903df")) {                    Plotly.newPlot(                        "1eb544fe-4300-4a82-8c82-41ba6e3903df",                        [{"hovertemplate":"Instance type=m5.4xlarge<br>factor=cpu<br>utilization fraction=%{x}<br>power [W]=%{y}<extra></extra>","legendgroup":"m5.4xlarge","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"m5.4xlarge","orientation":"v","showlegend":true,"x":[0.0,0.1,0.5,1.0],"xaxis":"x","y":[9.646666667,24.43833333,57.28333333,79.6625],"yaxis":"y","type":"scatter"},{"hovertemplate":"Instance type=m5.4xlarge<br>factor=ram<br>utilization fraction=%{x}<br>power [W]=%{y}<extra></extra>","legendgroup":"m5.4xlarge","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"m5.4xlarge","orientation":"v","showlegend":false,"x":[0.0,0.1,0.5,1.0],"xaxis":"x2","y":[9.635,15.39833333,39.68333333,63.96833333],"yaxis":"y2","type":"scatter"},{"hovertemplate":"Instance type=r5.4xlarge<br>factor=cpu<br>utilization fraction=%{x}<br>power [W]=%{y}<extra></extra>","legendgroup":"r5.4xlarge","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"r5.4xlarge","orientation":"v","showlegend":true,"x":[0.0,0.1,0.5,1.0],"xaxis":"x","y":[9.646666667,24.43833333,57.28333333,79.6625],"yaxis":"y","type":"scatter"},{"hovertemplate":"Instance type=r5.4xlarge<br>factor=ram<br>utilization fraction=%{x}<br>power [W]=%{y}<extra></extra>","legendgroup":"r5.4xlarge","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"r5.4xlarge","orientation":"v","showlegend":false,"x":[0.0,0.1,0.5,1.0],"xaxis":"x2","y":[19.27,30.79666667,79.36666667,127.9366667],"yaxis":"y2","type":"scatter"},{"hovertemplate":"Instance type=m4.4xlarge<br>factor=cpu<br>utilization fraction=%{x}<br>power [W]=%{y}<extra></extra>","legendgroup":"m4.4xlarge","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"m4.4xlarge","orientation":"v","showlegend":true,"x":[0.0,0.1,0.5,1.0],"xaxis":"x","y":[7.773333333,22.19111111,45.64222222,62.47388889],"yaxis":"y","type":"scatter"},{"hovertemplate":"Instance type=m4.4xlarge<br>factor=ram<br>utilization fraction=%{x}<br>power [W]=%{y}<extra></extra>","legendgroup":"m4.4xlarge","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"m4.4xlarge","orientation":"v","showlegend":false,"x":[0.0,0.1,0.5,1.0],"xaxis":"x2","y":[12.8,19.2,25.6,38.4],"yaxis":"y2","type":"scatter"},{"hovertemplate":"Instance type=c5d.4xlarge<br>factor=cpu<br>utilization fraction=%{x}<br>power [W]=%{y}<extra></extra>","legendgroup":"c5d.4xlarge","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"c5d.4xlarge","orientation":"v","showlegend":true,"x":[0.0,0.1,0.5,1.0],"xaxis":"x","y":[11.25777778,29.96666667,65.15777778,94.15111111],"yaxis":"y","type":"scatter"},{"hovertemplate":"Instance type=c5d.4xlarge<br>factor=ram<br>utilization fraction=%{x}<br>power [W]=%{y}<extra></extra>","legendgroup":"c5d.4xlarge","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"c5d.4xlarge","orientation":"v","showlegend":false,"x":[0.0,0.1,0.5,1.0],"xaxis":"x2","y":[6.223333333,11.24166667,19.74,28.23833333],"yaxis":"y2","type":"scatter"},{"hovertemplate":"Instance type=r5ad.4xlarge<br>factor=cpu<br>utilization fraction=%{x}<br>power [W]=%{y}<extra></extra>","legendgroup":"r5ad.4xlarge","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"line ...

# %% [markdown]
# ### Reshape dataframe from long to wide format, dimension: time * {pod_name, ...}

# %%
def get_subset_for_display(df, subsample_every=[10,18]):
    skip_num = [int(math.floor(df.shape[0] / subsample_every[0])),
                int(math.floor(df.shape[1] / subsample_every[1]))]
    df_ss = df.iloc[0::skip_num[0], 0::skip_num[1]]
    df_disp = df_ss.loc[df_ss.any(axis=1), :]
    df_disp = df_disp.loc[:, df_disp.any(axis=0)]

    return df_disp

# %%
pivot_cols = grouping_cols.copy()
pivot_cols.remove("time")
df_util = pd.pivot(df_dd, index="time", values=["util_frac"], columns=pivot_cols)
get_subset_for_display(df_util)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead tr th {
#         text-align: left;
#     }
#
#     .dataframe thead tr:last-of-type th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th colspan="5" halign="left">util_frac</th>
#     </tr>
#     <tr>
#       <th>query_value</th>
#       <th colspan="3" halign="left">memory</th>
#       <th colspan="2" halign="left">cpu</th>
#     </tr>
#     <tr>
#       <th>instance-type</th>
#       <th>m5.4xlarge</th>
#       <th>m5d.4xlarge</th>
#       <th>m5.8xlarge</th>
#       <th colspan="2" halign="left">m5.4xlarge</th>
#     </tr>
#     <tr>
#       <th>pod_name</th>
#       <th>eventspreprocessedred-1-10no-1641863769117-exec-11</th>
#       <th>eventspreprocessedyellow-1-10se-1641865659075-exec-27</th>
#       <th>eventspreprocessedyellow-1-10no-1641865659242-exec-10</th>
#       <th>ate-age-v2-usertensors-1dfa5bd583-xww7p</th>
#       <th>ate-age-v2-usertensors-0a03fe2dab-slxm6</th>
#     </tr>
#     <tr>
#       <th>stage_name</th>
#       <th>eventspreprocessed</th>
#       <th>eventspreprocessed</th>
#       <th>eventspreprocessed</th>
#       <th>usertensors</th>
#       <th>usertensors</th>
#     </tr>
#     <tr>
#       <th>time</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2022-01-11 01:38:00+00:00</th>
#       <td>0.397831</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2022-01-11 02:14:00+00:00</th>
#       <td>NaN</td>
#       <td>0.383533</td>
#       <td>0.101143</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2022-01-11 02:50:00+00:00</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.314430</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2022-01-11 03:26:00+00:00</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.311382</td>
#       <td>0.309154</td>
#     </tr>
#     <tr>
#       <th>2022-01-11 04:02:00+00:00</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.348518</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
px.histogram(df_util.notna().sum(axis=0), nbins=200) # num samples per pod
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="8314fd78-4506-4ba0-b7e7-c1414a65dd02" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8314fd78-4506-4ba0-b7e7-c1414a65dd02")) {                    Plotly.newPlot(                        "8314fd78-4506-4ba0-b7e7-c1414a65dd02",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=0<br>value=%{x}<br>count=%{y}<extra></extra>","legendgroup":"0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"0","nbinsx":200,"offsetgroup":"0","orientation":"v","showlegend":true,"x":[16,14,14,8,3,18,15,4,7,6,4,22,4,3,6,52,9,53,15,8,32,7,48,6,6,24,4,11,8,3,51,4,3,19,46,52,6,5,15,7,4,4,3,31,22,18,5,5,4,4,10,3,7,26,7,53,5,4,9,10,5,6,53,19,14,14,7,32,3,6,38,7,14,14,6,26,32,19,6,5,4,7,4,4,6,22,8,57,57,
4,17,4,17,9,5,18,8,4,19,23,52,54,6,14,50,8,14,3,5,14,44,4,6,44,4,11,4,14,14,6,4,3,75,4,53,5,26,4,3,57,19,14,4,14,12,14,3,4,51,74,7,9,22,4,3,14,22,7,20,6,14,4,53,76,8,14,6,37,52,4,4,4,14,18,4,53,5,5,21,6,34,4,4,18,25,5,14,10,4,14,14,4,3,7,8,26,6,2,19,14,8,14,50,4,7,8,50,5,6,44,6,3,9,54,4,4,3,3,5,5,4,4,6,32,5,4,14,3,6,15,52,4,16,4,8,7,3,4,4,7,4,10,3,14,3,4,6,5,3,6,22,11,7,14,10,4,21,5,4,29,2,3,9,14,7,51,3,19,57,77,3,14,6,6,22,5,4,4,6,50,7,46,4,22,5,8,12,14,7,14,22,4,4,18,5,5,73,50,52,4,3,3,4,5,5,3,6,4,6,44,7,4,54,15,53,6,3,48,6,4,8,6,50,4,14,3,26,6,4,24,5,8,50,14,5,53,5,55,7,4,4,4,4,50,4,31,3,14,9,5,8,50,5,3,14,19,6,4,15,18],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor" ...

# %% [markdown]
# ### Upsample to constant rate

# %%
sample_intervals = df_util.index.to_series().diff().value_counts()
resample_interval = sample_intervals.index.min()
sample_intervals, resample_interval
# Out:
# Out[18]: (0 days 00:02:00    185
#  0 days 00:04:00      1
#  Name: time, dtype: int64,
#  Timedelta('0 days 00:02:00'))

# %%
df_util_rs = df_util.asfreq(resample_interval, method="ffill")

# %%
# Check utils per instance-type:
util_summary = df_util_rs.mean(axis=0).groupby(["query_value", "instance-type"])
pd.concat([util_summary.mean(),
           util_summary.size()], axis=1).rename(columns={
    0:"mean_util_frac",
    1:"pod_count"
}).sort_values(["query_value", "pod_count"], ascending=False)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>mean_util_frac</th>
#       <th>pod_count</th>
#     </tr>
#     <tr>
#       <th>query_value</th>
#       <th>instance-type</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="10" valign="top">memory</th>
#       <th>r5.4xlarge</th>
#       <td>0.078708</td>
#       <td>110</td>
#     </tr>
#     <tr>
#       <th>m5.8xlarge</th>
#       <td>0.030593</td>
#       <td>106</td>
#     </tr>
#     <tr>
#       <th>m5.4xlarge</th>
#       <td>0.077930</td>
#       <td>79</td>
#     </tr>
#     <tr>
#       <th>r5a.4xlarge</th>
#       <td>0.091368</td>
#       <td>74</td>
#     </tr>
#     <tr>
#       <th>m4.4xlarge</th>
#       <td>0.081825</td>
#       <td>60</td>
#     </tr>
#     <tr>
#       <th>c5d.4xlarge</th>
#       <td>0.157299</td>
#       <td>42</td>
#     </tr>
#     <tr>
#       <th>r5ad.4xlarge</th>
#       <td>0.068562</td>
#       <td>34</td>
#     </tr>
#     <tr>
#       <th>c5.4xlarge</th>
#       <td>0.193832</td>
#       <td>24</td>
#     </tr>
#     <tr>
#       <th>m5d.4xlarge</th>
#       <td>0.139954</td>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>g4dn.4xlarge</th>
#       <td>0.329598</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th rowspan="10" valign="top">cpu</th>
#       <th>r5.4xlarge</th>
#       <td>0.240664</td>
#       <td>110</td>
#     </tr>
#     <tr>
#       <th>m5.8xlarge</th>
#       <td>0.130071</td>
#       <td>105</td>
#     </tr>
#     <tr>
#       <th>m5.4xlarge</th>
#       <td>0.277817</td>
#       <td>79</td>
#     </tr>
#     <tr>
#       <th>r5a.4xlarge</th>
#       <td>0.256637</td>
#       <td>74</td>
#     </tr>
#     <tr>
#       <th>m4.4xlarge</th>
#       <td>0.274365</td>
#       <td>60</td>
#     </tr>
#     <tr>
#       <th>c5d.4xlarge</th>
#       <td>0.285937</td>
#       <td>42</td>
#     </tr>
#     <tr>
#       <th>r5ad.4xlarge</th>
#       <td>0.275578</td>
#       <td>34</td>
#     </tr>
#     <tr>
#       <th>c5.4xlarge</th>
#       <td>0.288945</td>
#       <td>24</td>
#     </tr>
#     <tr>
#       <th>m5d.4xlarge</th>
#       <td>0.251272</td>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>g4dn.4xlarge</th>
#       <td>0.272403</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
## plot pod count on x-axis and utilization on y-axis for all instance types, for memory and another for CPU ## number of containers on x-axis

# %% [markdown]
# ### Calculate power delta and GPU power (from avg GPU util)

# %%
gpu_util_cols = ['GPUWatt @ Idle', 'GPUWatt @ 10%','GPUWatt @ 50%', 'GPUWatt @ 100%']
gpu_instances = df_ec2[df_ec2[gpu_util_cols].sum(axis=1) > 0]
gpu_instances[gpu_util_cols].T
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Instance type</th>
#       <th>g4dn.4xlarge</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>GPUWatt @ Idle</th>
#       <td>8.129003</td>
#     </tr>
#     <tr>
#       <th>GPUWatt @ 10%</th>
#       <td>22.278232</td>
#     </tr>
#     <tr>
#       <th>GPUWatt @ 50%</th>
#       <td>52.658457</td>
#     </tr>
#     <tr>
#       <th>GPUWatt @ 100%</th>
#       <td>71.298151</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
## sns.hitplot (data=df, x- Instance type, y=utilization)

# %%
def get_mean_gpu_power():
    df_gpu_instace_codecarbon = pd.read_csv("/databricks/driver/codecarbon_carbontracking.csv")
    mean_gpu_power = df_gpu_instace_codecarbon["gpu_power"].mean()
    return mean_gpu_power

# %%
def calc_total_power(df_util_rs, df_ec2, mean_gpu_power):

    instance_type_level_idx = np.where(np.array(df_util_rs.columns.names) == "instance-type")[0][0]
    query_value_level_idx = np.where(np.array(df_util_rs.columns.names) == "query_value")[0][0]

    def calc_power_util(df_util_rs):
        df_power_util = (df_util_rs
                         .apply(lambda ts: util_to_power(
                             df_ec2,
                             ts.values,
                             ts.name[query_value_level_idx],
                             ts.name[instance_type_level_idx]), axis=0)
                         .droplevel(0, axis=1))
        df_power_util = df_power_util.stack('query_value')
        df_power_util.index = (pd.MultiIndex
                               .from_tuples([(time, query_value) for time, query_value in df_power_util.index],
                                            names=["time", "power_factor"]))
        df_power_util = df_power_util.unstack('power_factor')
        return df_power_util

    def calc_delta_power(df_util_any_query, instance_type_level_idx_any_query):
        df_delta_power = (df_util_any_query
                          .apply(lambda ts: instace_type_util_to_delta_power(
                              df_ec2,
                              ts,
                              ts.name[instance_type_level_idx_any_query]), axis=0)
                          .droplevel(0, axis=1)
                          .assign(power_factor='delta')
                          .set_index('power_factor', append=True)
                          .unstack('power_factor')) # append multiindex level
        return df_delta_power

    def calc_gpu_power(df_util_any_query, instance_type_level_idx_any_quer, mean_gpu_power):
        df_gpu_power = (df_util_any_query
        .apply(lambda ts: instace_type_util_to_gpu_power(
            ts,
            ts.name[instance_type_level_idx_any_query],
            {i: mean_gpu_power for i in gpu_instances.index}), axis=0))
        df_gpu_power = (df_gpu_power
                        .droplevel(0, axis=1)
                        .assign(power_factor='gpu')
                        .set_index('power_factor', append=True)
                        .unstack('power_factor')) # append multiindex level
        return df_gpu_power

    df_util_any_query = df_util_rs.stack(query_value_level_idx).groupby("time").any()
    instance_type_level_idx_any_query = np.where(np.array(df_util_any_query.columns.names) == "instance-type")[0][0]

    return pd.concat([calc_power_util(df_util_rs),
                      calc_delta_power(df_util_any_query, instance_type_level_idx_any_query),
                      calc_gpu_power(df_util_any_query, instance_type_level_idx_any_query, mean_gpu_power)],
                     axis=1)

# %%
mean_gpu_power = get_mean_gpu_power()
df_power = calc_total_power(df_util_rs, df_ec2, mean_gpu_power)
get_subset_for_display(df_power)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead tr th {
#         text-align: left;
#     }
#
#     .dataframe thead tr:last-of-type th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th>instance-type</th>
#       <th>c5.4xlarge</th>
#       <th>c5d.4xlarge</th>
#       <th>m5.4xlarge</th>
#       <th>m5.8xlarge</th>
#       <th>r5.4xlarge</th>
#       <th>r5ad.4xlarge</th>
#       <th>m4.4xlarge</th>
#       <th>m5.8xlarge</th>
#       <th>r5.4xlarge</th>
#       <th>r5a.4xlarge</th>
#     </tr>
#     <tr>
#       <th>pod_name</th>
#       <th>ate-age-v2-usertensors-0379d73b1b-h5km9</th>
#       <th>eventspreprocessedred-1-10no-1641863769117-exec-22</th>
#       <th>ate-age-v2-usertensors-f28cff8fd8-74qjd</th>
#       <th>ate-age-v2-usertensors-673bea4442-kqwst</th>
#       <th>eventspreprocessedyellow-1-10no-1641865659242-exec-14</th>
#       <th>eventspreprocessedred-1-10no-1641863769117-exec-5</th>
#       <th>ate-age-v2-usertensors-fb63f827d1-zv8bf</th>
#       <th>ate-age-v2-usertensors-4cea9db07c-6z5fh</th>
#       <th>ate-age-v2-usertensors-7cc8ce6771-lhmpm</th>
#       <th>eventspreprocessedred-1-10se-1641864700389-exec-17</th>
#     </tr>
#     <tr>
#       <th>stage_name</th>
#       <th>usertensors</th>
#       <th>eventspreprocessed</th>
#       <th>usertensors</th>
#       <th>usertensors</th>
#       <th>eventspreprocessed</th>
#       <th>eventspreprocessed</th>
#       <th>usertensors</th>
#       <th>usertensors</th>
#       <th>usertensors</th>
#       <th>eventspreprocessed</th>
#     </tr>
#     <tr>
#       <th>power_factor</th>
#       <th>cpu</th>
#       <th>cpu</th>
#       <th>cpu</th>
#       <th>cpu</th>
#       <th>cpu</th>
#       <th>cpu</th>
#       <th>delta</th>
#       <th>delta</th>
#       <th>delta</th>
#       <th>delta</th>
#     </tr>
#     <tr>
#       <th>time</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2022-01-11 01:36:00+00:00</th>
#       <td>NaN</td>
#       <td>39.15748</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>31.00797</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>13.333333</td>
#     </tr>
#     <tr>
#       <th>2022-01-11 02:12:00+00:00</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>40.916839</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2022-01-11 02:48:00+00:00</th>
#       <td>48.799591</td>
#       <td>NaN</td>
#       <td>42.238738</td>
#       <td>65.769989</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td
,3954.8640592316156,3999.9176612192937,4437.255393604594,5766.82168383317,5682.926683107666,5978.55904207138,6068.313199358026,5987.086503995808,6289.140998994756,6442.606822649767,6261.691886360932,5951.5063768256,5903.320878273164,3064.5280013002093,2969.6540176738577,2969.6540176738577,2969.6540176738577],"yaxis":"y","type":"scatter"},{"hovertemplate":"stage_name=reachmetrics<br>time=%{x}<br>power=%{y}<extra></extra>","legendgroup":"reachmetrics","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"reachmetrics","orientation":"v","showlegend":true,"x":["2022-01-11T01:00:00+00:00","2022-01-11T01:02:00+00:00","2022-01-11T01:04:00+00:00","2022-01-11T01:46:00+00:00","2022-01-11T01:48:00+00:00","2022-01-11T01:50:00+00:00","2022-01-11T01:52:00+00:00","2022-01-11T01:54:00+00:00","2022-01-11T01:56:00+00:00"],"xaxis":"x","y":[125.18834698862037,125.18834698862037,125.18834698862037,177.04757392644171,273.45466976956675,274.77784276684764,283.12757945564147,283.12757945564147,145.83187893003137],"yaxis":"y","type":"scatter"},{"hovertemplate":"stage_name=usertensors<br>time=%{x}<br>power=%{y}<extra></extra>","legendgroup":"usertensors","line":{"color":"#00cc96","dash":"solid"},"marker":{"symb ...

# %%
df_dE = df_power * resample_interval / np.timedelta64(1, 'h') / 1000 # delta Energy in kWh per sample

# %%
df_E_stage = df_dE.sum(axis=0).groupby(["stage_name", "power_factor"]).sum().unstack("power_factor")
df_E_stage = df_E_stage[df_E_stage.sum(axis=0).sort_values(ascending=False).index]
df_E_stage = df_E_stage.loc[df_E_stage.sum(axis=1).sort_values(ascending=False).index]
df_E_stage[df_E_stage == 0.0] = np.nan
energy_plot_data = pd.melt(df_E_stage.reset_index(),
                    id_vars=['stage_name'],
                    value_vars=['cpu', 'memory', 'delta', 'gpu'])

# %%
alt.Chart(energy_plot_data).mark_rect().encode(
    x=alt.X('power_factor', sort=['cpu', 'memory', 'delta', 'gpu'], axis=alt.Axis(title='Power factor')),
    y=alt.Y('stage_name', axis=alt.Axis(title='Pipeline stage')),
    color=alt.Color('value',scale=alt.Scale(type='log',scheme='greenblue'), title="kWh")
).properties(
    width=700,
    height=300
)
# Out:
# <style>
#   #altair-viz-a30da0aa7d624525b2653eb250b097ba.vega-embed {
#     width: 100%;
#     display: flex;
#   }
#
#   #altair-viz-a30da0aa7d624525b2653eb250b097ba.vega-embed details,
#   #altair-viz-a30da0aa7d624525b2653eb250b097ba.vega-embed details summary {
#     position: relative;
#   }
# </style>
# <div id="altair-viz-a30da0aa7d624525b2653eb250b097ba"></div>
# <script type="text/javascript">
#   var VEGA_DEBUG = (typeof VEGA_DEBUG == "undefined") ? {} : VEGA_DEBUG;
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-a30da0aa7d624525b2653eb250b097ba") {
#       outputDiv = document.getElementById("altair-viz-a30da0aa7d624525b2653eb250b097ba");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm/vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm/vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm/vega-lite@5.17.0?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm/vega-embed@6?noext",
#     };
#
#     function maybeLoadScript(lib, version) {
#       var key = `${lib.replace("-", "")}_version`;
#       return (VEGA_DEBUG[key] == version) ?
#         Promise.resolve(paths[lib]) :
#         new Promise(function(resolve, reject) {
#           var s = document.createElement('script');
#           document.getElementsByTagName("head")[0].appendChild(s);
#           s.async = true;
#           s.onload = () => {
#             VEGA_DEBUG[key] = version;
#             return resolve(paths[lib]);
#           };
#           s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#           s.src = paths[lib];
#         });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else {
#       maybeLoadScript("vega", "5")
#         .then(() => maybeLoadScript("vega-lite", "5.17.0"))
#         .then(() => maybeLoadScript("vega-embed", "6"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 300, "continuousHeight": 300}}, "data": {"name": "data-086ef8fc44c9aa10d703c4b80bcaed2e"}, "mark": {"type": "rect"}, "encoding": {"color": {"field": "value", "scale": {"scheme": "greenblue", "type": "log"}, "title": "kWh", "type": "quantitative"}, "x": {"axis": {"title": "Power factor"}, "field": "power_factor", "sort": ["cpu", "memory", "delta", "gpu"], "type": "nominal"}, "y": {"axis": {"title": "Pipeline stage"}, "field": "stage_name", "type": "nominal"}}, "height": 300, "width": 700, "$schema": "https://vega.github.io/schema/vega-lite/v5.17.0.json", "datasets": {"data-086ef8fc44c9aa10d703c4b80bcaed2e": [{"stage_name": "usertensors", "power_factor": "cpu", "value": 9.088757470752235}, {"stage_name": "eventspreprocessed", "power_factor": "cpu", "value": 2.710882497997524}, {"stage_name": "modeltrainin", "power_factor": "cpu", "value": 0.20638311262773112}, {"stage_name": "userpredicti", "power_factor": "cpu", "value": 0.1924488721544489}, {"stage_name": "predictionspostprocessed", "power_factor": "cpu", "value": 0.0451829330518125}, {"stage_name": "reachmetrics", "power_factor": "cpu", "value": 0.01912769838109111}, {"stage_name": "metricsreporter", "power_factor": "cpu", "value": 0.0071626996249005564}, {"stage_name": "usertensors", "power_factor": "memory", "value": 3.5567879265060354}, {"stage_name": "eventspreprocessed", "power_factor": "memory", "value": 2.6604290525721734}, {"stage_name": "modeltrainin", "power_factor": "memory", "value": 0.1569164737578236}, {"stage_name": "userpredicti", "power_factor": "memory", "value": 0.06624498136131889}, {"stage_name": "predictionspostprocessed", "power_factor": "memory", "value": 0.037227934356071114}, {"stage_name": "reachmetrics", "power_factor": "memory", "value": 0.019747818239569722}, {"stage_name": "metricsreporter", "power_factor": "memory", "value": 0.010546187973606944}, {"stage_name": "usertensors", "power_factor": "delta", "value": 3.785081481338667}, {"stage_name": "eventspreprocessed", "power_factor": "delta", "value": 1.4006222221146667}, {"stage_name": "modeltrainin", "power_factor": "delta", "value": 0.07793333333333333}, {"stage_name": "userpredicti", "power_factor": "delta", "value": 0.09493333333333333}, {"stage_name": "predictionspostprocessed", "power_factor": "delta", "value": 0.048207407407333334}, {"stage_name": "reachmetrics", "power_factor": "delta", "value": 0.021555555555}, {"stage_name": "metricsreporter", "power_factor": "delta", "value": 0.011599999999666669}, {"stage_name": "usertensors", "power_factor": "gpu", "value": null}, {"stage_name": "eventspreprocessed", "power_factor": "gpu", "value": null}, {"stage_name": "modeltrainin", "power_factor": "gpu", "value": 0.18020413333333332}, {"stage_name": "userpredicti", "power_factor": "gpu", "value": null}, {"stage_name": "predictionspostprocessed", "power_factor": "gpu", "value": null}, {"stage_name": "reachmetrics", "power_factor": "gpu", "value": null}, {"stage_name": "metricsreporter", "power_factor": "gpu", "value": null}]}}, {"mode": "vega-lite"});
# </script>

# %%
## heatmap from seaborn --> coorrelation between power factor and pipeline stage---heatmap

# %% [markdown]
# ### Convert to CO2eq

# %%
my_region = "eu-west-1"

def df_dE_to_co2e(df_dE, region, df_intensity):
    pue = df_intensity.loc[region]["PUE"]
    co2e_intensity = df_intensity.loc[region]["CO2e (metric gram/kWh)"]

    df_dco2e = df_dE * pue * co2e_intensity # CO2e in gram per sample
    df_dco2e = df_dco2e.rename_axis(columns={"power_factor": "co2e_factor"})
    return df_dco2e

df_dco2e = df_dE_to_co2e(df_dE, my_region, df_intensity)

# %%
df_dco2e.sum().sum() # total scope 2 emissions in gCO2eq
# Out:
# Out[32]: 9251.715201292618

# %%
def concat_scope3_emissions(df_dco2e, df_ec2): # move df_dE_to_co2e into here to avoid state changes

    def instace_type_kwh_to_co2e(any_sample_values, instance_type):
        return any_sample_values.map({True: df_ec2.loc[instance_type].loc["Instance Hourly Manufacturing Emissions (gCO₂eq)"] * resample_interval / np.timedelta64(1, 'h'), False: np.nan})

    df_dco2e_any_factor = df_dco2e.stack("co2e_factor").groupby("time").any()
    instance_type_level_idx_any_factor = np.where(np.array(df_dco2e_any_factor.columns.names) == "instance-type")[0][0]

    df_dco2e = pd.concat([df_dco2e,
                         df_dco2e_any_factor.apply(
        lambda ts: instace_type_kwh_to_co2e(ts, ts.name[instance_type_level_idx_any_factor]), axis=0
    ).assign(co2e_factor='manufacturing').set_index('co2e_factor', append=True).unstack('co2e_factor')]) # append multiindex level

    return df_dco2e

df_dco2e = concat_scope3_emissions(df_dco2e, df_ec2)

# %%
df_dco2e.sum().sum() # total emissions in gCO2eq
# Out:
# Out[34]: 12385.687252709093

# %%
px.line((df_dco2e
         .stack("co2e_factor")
         .sum(axis=1)
         .reset_index(1)
         .rename(columns={0:"gCO2eq"})),
        y="gCO2eq",
        color="co2e_factor")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="20873fe9-1728-4eda-8f26-76b30340160c" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("20873fe9-1728-4eda-8f26-76b30340160c")) {                    Plotly.newPlot(                        "20873fe9-1728-4eda-8f26-76b30340160c",                        [{"hovertemplate":"co2e_factor=cpu<br>time=%{x}<br>gCO2eq=%{y}<extra></extra>","legendgroup":"cpu","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":
2022-01-11T04:00:00+00:00","2022-01-11T04:02:00+00:00","2022-01-11T04:04:00+00:00","2022-01-11T04:06:00+00:00","2022-01-11T04:08:00+00:00","2022-01-11T04:10:00+00:00","2022-01-11T04:12:00+00:00","2022-01-11T04:14:00+00:00","2022-01-11T04:16:00+00:00","2022-01-11T04:18:00+00:00","2022-01-11T04:20:00+00:00","2022-01-11T04:22:00+00:00","2022-01-11T04:24:00+00:00","2022-01-11T04:26:00+00:00","2022-01-11T04:28:00+00:00","2022-01-11T04:30:00+00:00","2022-01-11T04:32:00+00:00","2022-01-11T04:34:00+00:00","2022-01-11T04:36:00+00:00","2022-01-11T04:38:00+00:00","2022-01-11T04:40:00+00:00","2022-01-11T04:42:00+00:00","2022-01-11T04:44:00+00:00","2022-01-11T04:46:00+00:00","2022-01-11T04:48:00+00: ...

# %%
# Check saving for greener region
concat_scope3_emissions(
    df_dE_to_co2e(
        df_dE, "eu-north-1", df_intensity), df_ec2).sum().sum() / df_dco2e.sum().sum()
# Out:
# Out[36]: 0.2719423331706656

# %% [markdown]
# ### Fraction of scope 2 out of total

# %%
co2e_per_factor = df_dco2e.sum(axis=0).groupby("co2e_factor").sum()
px.bar(co2e_per_factor.sort_values(ascending=False)).update_layout(
    title="Emissions by factor",
    yaxis_title="CO2eq [g]")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="4d143cd8-0930-457b-b323-f6d5dd6f8196" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4d143cd8-0930-457b-b323-f6d5dd6f8196")) {                    Plotly.newPlot(                        "4d143cd8-0930-457b-b323-f6d5dd6f8196",                        [{"alignmentgroup":"True","hovertemplate":"variable=0<br>co2e_factor=%{x}<br>value=%{y}<extra></extra>","legendgroup":"0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"v","showlegend":true,"textposition":"auto","x":["cpu","manufacturing","memory","delta","gpu"],"xaxis":"x","y":[4652.76325191643,3133.9720514164737,2467.795822111494,2062.8227199046946,68.33340736],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{ ...

# %%
scope_3_co2e_factors = ["manufacturing"]
scope_2_co2e_factors = co2e_per_factor.index.drop(scope_3_co2e_factors)
print("Manufacturing fraction of all emissions:")
co2e_per_factor[scope_3_co2e_factors] / co2e_per_factor.sum()
# Out:
# Manufacturing fraction of all emissions:
# Out[38]: co2e_factor
# manufacturing    0.253032
# dtype: float64

# %% [markdown]
# ### Plot by CO2eq factor

# %%
df_dco2e.stack(["stage_name"]).groupby(["time","stage_name"]).sum().sum(axis=1)
# Out:
# Out[39]: time                       stage_name
# 2022-01-11 01:00:00+00:00  eventspreprocessed           4.267434
#                            reachmetrics                 2.407232
# 2022-01-11 01:02:00+00:00  eventspreprocessed          32.560676
#                            reachmetrics                 2.407232
# 2022-01-11 01:04:00+00:00  eventspreprocessed          45.729159
#                                                          ...
# 2022-01-11 07:12:00+00:00  metricsreporter              2.288919
#                            predictionspostprocessed     2.611730
#                            userpredicti                 2.335077
# 2022-01-11 07:14:00+00:00  metricsreporter              2.197873
#                            predictionspostprocessed     2.611730
# Length: 423, dtype: float64

# %%
px.line(
    pd.melt((df_dco2e
             .stack(["stage_name"])
             .groupby(["time","stage_name"])
             .sum()
             .sum(axis=1)
             .unstack(["stage_name"])),
        ignore_index=False, value_name="co2e"),
    color="stage_name"
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id
01-11T03:28:00+00:00","2022-01-11T03:30:00+00:00","2022-01-11T03:32:00+00:00","2022-01-11T03:34:00+00:00","2022-01-11T03:36:00+00:00","2022-01-11T03:38:00+00:00","2022-01-11T03:40:00+00:00","2022-01-11T03:42:00+00:00","2022-01-11T03:44:00+00:00","2022-01-11T03:46:00+00:00","2022-01-11T03:48:00+00:00","2022-01-11T03:50:00+00:00","2022-01-11T03:52:00+00:00","2022-01-11T03:54:00+00:00","2022-01-11T03:56:00+00:00","2022-01-11T03:58:00+00:00","2022-01-11T04:00:00+00:00","2022-01-11T04:02:00+00:00","2022-01-11T04:04:00+00:00","2022-01-11T04:06:00+00:00","2022-01-11T04:08:00+00:00","2022-01-11T04:10:00+00:00","2022-01-11T04:12:00+00:00","2022-01-11T04:14:00+00:00","2022-01-11T04:16:00+00:00","2022-01-11T04:18:00+00:00","2022-01-11T04:20:00+00:00","2022-01-11T04:22:00+00:00","2022-01-11T04:24:00+00:00","2022-01-11T04:26:00+00:00","2022-01-11T04:28:00+00:00","2022-01-11T04:30:00+00:00","2022-01-11T04:32:00+00:00","2022-01-11T04:34:00+00:00","2022-01-11T04:36:00+00:00","2022-01-11T04:38:00+00:00","2022-01-11T04:40:00+00:00","2022-01-11T04:42:00+00:00","2022-01-11T04:44:00+00:00","2022-01-1 ...

# %%
df_co2e_stage = df_dco2e.sum(axis=0).groupby(["stage_name", "co2e_factor"]).sum().unstack("co2e_factor")
df_co2e_stage = df_co2e_stage[df_co2e_stage.sum(axis=0).sort_values(ascending=False).index]
df_co2e_stage = df_co2e_stage.loc[df_co2e_stage.sum(axis=1).sort_values(ascending=False).index]
df_co2e_stage[df_co2e_stage == 0.0] = np.nan
plot_data = pd.melt(df_co2e_stage.reset_index(),
                    id_vars=['stage_name'],
                    value_vars=['cpu', 'memory', 'delta', 'gpu'])

# %%
alt.Chart(plot_data).mark_rect().encode(
    x=alt.X('co2e_factor',
            sort=['cpu', 'memory', 'delta', 'gpu'],
            axis=alt.Axis(title='CO2e factor')),
    y=alt.Y('stage_name',
            sort=['metricsreporter', 'reachmetrics', 'predictionspostprocessed',
                  'userpredicti', 'modeltrainin', 'eventspreprocessed', 'usertensors'],
            axis=alt.Axis(title='Pipeline stage')),
    color=alt.Color('value',scale=alt.Scale(type='log',scheme='greenblue'), title="CO2eq [g]")
).properties(
    width=700,
    height=300
)
# Out:
# <style>
#   #altair-viz-93883374ecfd4f3e84efd25e439537b1.vega-embed {
#     width: 100%;
#     display: flex;
#   }
#
#   #altair-viz-93883374ecfd4f3e84efd25e439537b1.vega-embed details,
#   #altair-viz-93883374ecfd4f3e84efd25e439537b1.vega-embed details summary {
#     position: relative;
#   }
# </style>
# <div id="altair-viz-93883374ecfd4f3e84efd25e439537b1"></div>
# <script type="text/javascript">
#   var VEGA_DEBUG = (typeof VEGA_DEBUG == "undefined") ? {} : VEGA_DEBUG;
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-93883374ecfd4f3e84efd25e439537b1") {
#       outputDiv = document.getElementById("altair-viz-93883374ecfd4f3e84efd25e439537b1");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm/vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm/vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm/vega-lite@5.17.0?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm/vega-embed@6?noext",
#     };
#
#     function maybeLoadScript(lib, version) {
#       var key = `${lib.replace("-", "")}_version`;
#       return (VEGA_DEBUG[key] == version) ?
#         Promise.resolve(paths[lib]) :
#         new Promise(function(resolve, reject) {
#           var s = document.createElement('script');
#           document.getElementsByTagName("head")[0].appendChild(s);
#           s.async = true;
#           s.onload = () => {
#             VEGA_DEBUG[key] = version;
#             return resolve(paths[lib]);
#           };
#           s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#           s.src = paths[lib];
#         });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else {
#       maybeLoadScript("vega", "5")
#         .then(() => maybeLoadScript("vega-lite", "5.17.0"))
#         .then(() => maybeLoadScript("vega-embed", "6"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"config": {"view": {"continuousWidth": 300, "continuousHeight": 300}}, "data": {"name": "data-1183f9f17177d7f9d0d58e2b4ba04bbe"}, "mark": {"type": "rect"}, "encoding": {"color": {"field": "value", "scale": {"scheme": "greenblue", "type": "log"}, "title": "CO2eq [g]", "type": "quantitative"}, "x": {"axis": {"title": "CO2e factor"}, "field": "co2e_factor", "sort": ["cpu", "memory", "delta", "gpu"], "type": "nominal"}, "y": {"axis": {"title": "Pipeline stage"}, "field": "stage_name", "sort": ["metricsreporter", "reachmetrics", "predictionspostprocessed", "userpredicti", "modeltrainin", "eventspreprocessed", "usertensors"], "type": "nominal"}}, "height": 300, "width": 700, "$schema": "https://vega.github.io/schema/vega-lite/v5.17.0.json", "datasets": {"data-1183f9f17177d7f9d0d58e2b4ba04bbe": [{"stage_name": "usertensors", "co2e_factor": "cpu", "value": 3446.456832909247}, {"stage_name": "eventspreprocessed", "co2e_factor": "cpu", "value": 1027.966643240661}, {"stage_name": "modeltrainin", "co2e_factor": "cpu", "value": 78.26047630843564}, {"stage_name": "userpredicti", "co2e_factor": "cpu", "value": 72.976612320967}, {"stage_name": "predictionspostprocessed", "co2e_factor": "cpu", "value": 17.1333682132473}, {"stage_name": "reachmetrics", "co2e_factor": "cpu", "value": 7.253223226109749}, {"stage_name": "metricsreporter", "co2e_factor": "cpu", "value": 2.716095697762291}, {"stage_name": "usertensors", "co2e_factor": "memory", "value": 1348.7339817310885}, {"stage_name": "eventspreprocessed", "co2e_factor": "memory", "value": 1008.8346967353681}, {"stage_name": "modeltrainin", "co2e_factor": "memory", "value": 59.50272684896672}, {"stage_name": "userpredicti", "co2e_factor": "memory", "value": 25.120096932212125}, {"stage_name": "predictionspostprocessed", "co2e_factor": "memory", "value": 14.116832707822164}, {"stage_name": "reachmetrics", "co2e_factor": "memory", "value": 7.488372676444838}, {"stage_name": "metricsreporter", "co2e_factor": "memory", "value": 3.9991144795917535}, {"stage_name": "usertensors", "co2e_factor": "delta", "value": 1435.3028977236224}, {"stage_name": "eventspreprocessed", "co2e_factor": "delta", "value": 531.1159466258816}, {"stage_name": "modeltrainin", "co2e_factor": "delta", "value": 29.552319999999995}, {"stage_name": "userpredicti", "co2e_factor": "delta", "value": 35.99872}, {"stage_name": "predictionspostprocessed", "co2e_factor": "delta", "value": 18.2802488888608}, {"stage_name": "reachmetrics", "co2e_factor": "delta", "value": 8.173866666456}, {"stage_name": "metricsreporter", "co2e_factor": "delta", "value": 4.398719999873601}, {"stage_name": "usertensors", "co2e_factor": "gpu", "value": null}, {"stage_name": "eventspreprocessed", "co2e_factor": "gpu", "value": null}, {"stage_name": "modeltrainin", "co2e_factor": "gpu", "value": 68.33340736}, {"stage_name": "userpredicti", "co2e_factor": "gpu", "value": null}, {"stage_name": "predictionspostprocessed", "co2e_factor": "gpu", "value": null}, {"stage_name": "reachmetrics", "co2e_factor": "gpu", "value": null}, {"stage_name": "metricsreporter", "co2e_factor": "gpu", "value": null}]}}, {"mode": "vega-lite"});
# </script>

# %%
px.bar(df_co2e_stage.sum(axis=1)).update_layout(
    title="Emissions by stage",
    yaxis_title="CO2eq [g]")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="50f1aa6e-70de-4982-bc47-2089ea951bcc" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("50f1aa6e-70de-4982-bc47-2089ea951bcc")) {                    Plotly.newPlot(                        "50f1aa6e-70de-4982-bc47-2089ea951bcc",                        [{"alignmentgroup":"True","hovertemplate":"variable=0<br>stage_name=%{x}<br>value=%{y}<extra></extra>","legendgroup":"0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"v","showlegend":true,"textposition":"auto","x":["usertensors","eventspreprocessed","modeltrainin","userpredicti","predictionspostprocessed","reachmetrics","metricsreporter"],"xaxis":"x","y":[8341.531612002254,3419.715628822588,316.46382992406905,180.51675384151247,74.7726657737636,34.87445150984392,17.812310835060977],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"col ...

# %% [markdown]
# ### Verify against an earlier codecarbon run

# %%
# Compare again old codecarbon estimate
1000 * 1658.9217151355867 / 365 # in gCO2eq, neither PUE or scope 3 applied
# Out:
# Out[44]: 4544.99100037147

# %%
# compare with adapted total based on cpu and gpu measurements for the same stages
codecarbon_co2e_intensity = 617.0 # g/kWh - this was about 2x to the value from df_intensity fore eu-west-1
df_dco2e = df_dE * codecarbon_co2e_intensity # CO2e in gram per sample
df_dco2e = df_dco2e.rename_axis(columns={"power_factor": "co2e_factor"})
get_subset_for_display(df_dco2e)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead tr th {
#         text-align: left;
#     }
#
#     .dataframe thead tr:last-of-type th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th>instance-type</th>
#       <th>c5.4xlarge</th>
#       <th>c5d.4xlarge</th>
#       <th>m5.4xlarge</th>
#       <th>m5.8xlarge</th>
#       <th>r5.4xlarge</th>
#       <th>r5ad.4xlarge</th>
#       <th>m4.4xlarge</th>
#       <th>m5.8xlarge</th>
#       <th>r5.4xlarge</th>
#       <th>r5a.4xlarge</th>
#     </tr>
#     <tr>
#       <th>pod_name</th>
#       <th>ate-age-v2-usertensors-0379d73b1b-h5km9</th>
#       <th>eventspreprocessedred-1-10no-1641863769117-exec-22</th>
#       <th>ate-age-v2-usertensors-f28cff8fd8-74qjd</th>
#       <th>ate-age-v2-usertensors-673bea4442-kqwst</th>
#       <th>eventspreprocessedyellow-1-10no-1641865659242-exec-14</th>
#       <th>eventspreprocessedred-1-10no-1641863769117-exec-5</th>
#       <th>ate-age-v2-usertensors-fb63f827d1-zv8bf</th>
#       <th>ate-age-v2-usertensors-4cea9db07c-6z5fh</th>
#       <th>ate-age-v2-usertensors-7cc8ce6771-lhmpm</th>
#       <th>eventspreprocessedred-1-10se-1641864700389-exec-17</th>
#     </tr>
#     <tr>
#       <th>stage_name</th>
#       <th>usertensors</th>
#       <th>eventspreprocessed</th>
#       <th>usertensors</th>
#       <th>usertensors</th>
#       <th>eventspreprocessed</th>
#       <th>eventspreprocessed</th>
#       <th>usertensors</th>
#       <th>usertensors</th>
#       <th>usertensors</th>
#       <th>eventspreprocessed</th>
#     </tr>
#     <tr>
#       <th>co2e_factor</th>
#       <th>cpu</th>
#       <th>cpu</th>
#       <th>cpu</th>
#       <th>cpu</th>
#       <th>cpu</th>
#       <th>cpu</th>
#       <th>delta</th>
#       <th>delta</th>
#       <th>delta</th>
#       <th>delta</th>
#     </tr>
#     <tr>
#       <th>time</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2022-01-11 01:36:00+00:00</th>
#       <td>NaN</td>
#       <td>0.805339</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.637731</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.274222</td>
#     </tr>
#     <tr>
#       <th>2022-01-11 02:12:00+00:00</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.841523</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2022-01-11 02:48:00+00:00</th>
#       <td>1.003645</td>
#       <td>NaN</td>
#       <td>0.868710</td>
#       <td>1.352669</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.265081</td>
#       <td>0.658133</td>
#       <td>0.329067</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2022-01-11 03:24:00+00:00</th>
#       <td>1.083291</td>
#       <td>NaN</td>
#       <td>0.881494</td>
#       <td>1.228677</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.265081</td>
#       <td>0.658133</td>
#       <td>0.329067</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2022-01-11 04:00:00+00:00</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.987702</td>
#       <td>1.239267</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.658133</td>
#       <td>0.329067</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df_dco2e.sum(axis=0).groupby(["stage_name", "co2e_factor"]).sum().unstack("co2e_factor")[["cpu", "gpu"]].loc[["modeltrainin", "userpredicti", "usertensors"]].sum().sum()
# Out:
# Out[46]: 5965.0286443314

# %%
model_comparison_df = pd.DataFrame.from_dict({
    "model":["Transformer(base)", "Transformer(big)", "ELMo", "BERT(base)", "DL pipeline"],
    "emission": [11.7934, 87.0897, 118.841, 652.26583, 12.386]})
px.bar(y=model_comparison_df['emission'],
       x=model_comparison_df['model']).update_layout(
    title="Carbon footprint of different models",
    yaxis_title="CO2eq [kg]",
    xaxis_title=None)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="238748e4-2717-4282-9a41-1052afbb064d" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("238748e4-2717-4282-9a41-1052afbb064d")) {                    Plotly.newPlot(                        "238748e4-2717-4282-9a41-1052afbb064d",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Transformer(base)","Transformer(big)","ELMo","BERT(base)","Schibsted DL pipeline"],"xaxis":"x","y":[11.7934,87.0897,118.841,652.26583,12.386],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks" ...
